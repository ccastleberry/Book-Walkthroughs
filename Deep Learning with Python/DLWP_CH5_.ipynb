# %% [markdown]
# <a href="https://colab.research.google.com/github/ccastleberry/Book-Walkthroughs/blob/master/Deep%20Learning%20with%20Python/DLWP_CH5_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Installs and Imports

# %%
# !pip install tensorflow==2.0.0

# %%
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.0.0

# %%
from tensorflow.keras import layers, models

# %% [markdown]
# # Build Model

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (5, 5), activation='relu', input_shape=(28, 28, 1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_3 (Conv2D)            (None, 24, 24, 32)        832
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 10, 10, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 3, 3, 64)          36928
# ...
# Total params: 56,256
# Trainable params: 56,256
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_3 (Conv2D)            (None, 24, 24, 32)        832
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 10, 10, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 3, 3, 64)          36928
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                36928
# ...

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
train_labels
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
train_labels.shape
# Out:
# (60000,)

# %%
train_images = train_images.reshape((60000, 28, 28, 1))
train_images = train_images.astype('float32') / 255
test_images = test_images.reshape((10000, 28, 28, 1))
test_images = test_images.astype('float32') / 255

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
train_labels.shape
# Out:
# (60000, 10)

# %%
model.compile(
    optimizer='rmsprop',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
model.fit(train_images, train_labels, epochs=5, batch_size=64)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 60s 1ms/sample - loss: 0.1702 - accuracy: 0.9465
# Epoch 2/5
# 60000/60000 [==============================] - 58s 964us/sample - loss: 0.0461 - accuracy: 0.9855
# Epoch 3/5
# 60000/60000 [==============================] - 58s 965us/sample - loss: 0.0327 - accuracy: 0.9896
# Epoch 4/5
# 60000/60000 [==============================] - 58s 964us/sample - loss: 0.0254 - accuracy: 0.9924
# Epoch 5/5
# 60000/60000 [==============================] - 58s 966us/sample - loss: 0.0200 - accuracy: 0.9939

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f'Test Loss: {test_loss}')
print(f'Test Accuracy: {test_acc}')
# Out:
# 10000/1 [=============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# ...

# %% [markdown]
# # DVC

# %%
import os, shutil
from pathlib import Path

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
data_set_dir = Path('/', 'content', 'drive', 'My Drive', 'Data_Sets')

# %%
cvd_dir = data_set_dir.joinpath('cats_and_dogs')

# %%
original_dataset_dir = cvd_dir.joinpath('original_data', 'train', 'train')

# %%
base_dir = cvd_dir.joinpath('cats_and_dogs_small')

# %%
train_dir = base_dir.joinpath('train')
if not train_dir.exists(): os.mkdir(train_dir)
val_dir = base_dir.joinpath('validation')
if not val_dir.exists(): os.mkdir(val_dir)
test_dir = base_dir.joinpath('test')
if not test_dir.exists(): os.mkdir(test_dir)

# %%
train_cats_dir = train_dir.joinpath("cats")
if not train_cats_dir.exists(): os.mkdir(train_cats_dir)
val_cats_dir = val_dir.joinpath("cats")
if not val_cats_dir.exists(): os.mkdir(val_cats_dir)
test_cats_dir = test_dir.joinpath("cats")
if not test_cats_dir.exists(): os.mkdir(test_cats_dir)
train_dogs_dir = train_dir.joinpath("dogs")
if not train_dogs_dir.exists(): os.mkdir(train_dogs_dir)
val_dogs_dir = val_dir.joinpath("dogs")
if not val_dogs_dir.exists(): os.mkdir(val_dogs_dir)
test_dogs_dir = test_dir.joinpath("dogs")
if not test_dogs_dir.exists(): os.mkdir(test_dogs_dir)

# %%
fnames = [f'cat.{i}.jpg' for i in range(1000)]
for fname in fnames:
  src = original_dataset_dir.joinpath(fname)
  dst = train_cats_dir.joinpath(fname)
  try:
    shutil.copyfile(src, dst)
  except:
    pass

fnames = [f'cat.{i}.jpg' for i in range(1000, 1500)]
for fname in fnames:
  src = original_dataset_dir.joinpath(fname)
  dst = val_cats_dir.joinpath(fname)
  try:
    shutil.copyfile(src, dst)
  except:
    pass 

fnames = [f'cat.{i}.jpg' for i in range(1500, 2000)]
for fname in fnames:
  src = original_dataset_dir.joinpath(fname)
  dst = test_cats_dir.joinpath(fname)
  try:
    shutil.copyfile(src, dst)
  except:
    pass

fnames = [f'dog.{i}.jpg' for i in range(1000)]
for fname in fnames:
  src = original_dataset_dir.joinpath(fname)
  dst = train_cats_dir.joinpath(fname)
  try:
    shutil.copyfile(src, dst)
  except:
    pass

fnames = [f'dog.{i}.jpg' for i in range(1000, 1500)]
for fname in fnames:
  src = original_dataset_dir.joinpath(fname)
  dst = val_cats_dir.joinpath(fname)
  try:
    shutil.copyfile(src, dst)
  except:
    pass 

fnames = [f'dog.{i}.jpg' for i in range(1500, 2000)]
for fname in fnames:
  src = original_dataset_dir.joinpath(fname)
  dst = test_cats_dir.joinpath(fname)
  try:
    shutil.copyfile(src, dst)
  except:
    pass
